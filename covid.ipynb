# %%
import os
import pandas as pd
import numpy as np

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
base_dir = '584020_1069347_bundle_archive/covid'

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# Directory with our training cat/dog pictures
train_class1_dir = os.path.join(train_dir, 'ct_covid')
train_class2_dir = os.path.join(train_dir, 'ct_non')

# Directory with our validation cat/dog pictures
validation_class1_dir = os.path.join(validation_dir, 'ct_covid')
validation_class2_dir = os.path.join(validation_dir, 'ct_covid')

# %%
train_class1_fnames = os.listdir( train_class1_dir)
train_class2_fnames = os.listdir( train_class2_dir)

print(train_class1_fnames[:10])
print(train_class2_fnames[:10])
# Out:
# ['2019-novel-Coronavirus-severe-adult-respiratory-dist_2020_International-Jour-p3-89%0.png', '2019-novel-Coronavirus-severe-adult-respiratory-dist_2020_International-Jour-p3-89%1.png', '2019-novel-Coronavirus-severe-adult-respiratory-dist_2020_International-Jour-p3-91.png', '2020.01.24.919183-p27-132.png', '2020.01.24.919183-p27-133.png', '2020.01.24.919183-p27-134.png', '2020.01.24.919183-p27-135.png', '2020.02.10.20021584-p6-52%0.png', '2020.02.10.20021584-p6-52%1.png', '2020.02.10.20021584-p6-52%10.png']
# ['1101.png', '1115.png', '112.png', '1123.png', '1124.png', '114.png', '115.png', '116.png', '1164.png', '117.png']

# %%
class1_name = 'ct_covid'
class2_name = 'ct_non'

print(f'total training {class1_name} images :', len(os.listdir(      train_class1_dir ) ))
print(f'total training {class2_name} images :', len(os.listdir(      train_class2_dir ) ))

print(f'total validation {class1_name} images :', len(os.listdir( validation_class1_dir ) ))
print(f'total validation {class2_name} images :', len(os.listdir( validation_class2_dir ) ))
# Out:
# total training ct_covid images : 319
# total training ct_non images : 331
# total validation ct_covid images : 25
# total validation ct_non images : 25

# %%
number_of_image = 2*4

nrows = number_of_image / 2
ncols = number_of_image / 2

pic_index = 0 

# Index for iterating over images
# Set up matplotlib fig, and size it to fit 4x4 pics


fig = plt.gcf()
fig.set_size_inches(ncols* number_of_image / 2, nrows* number_of_image / 2)

pic_index+= number_of_image

next_class1_pix = [os.path.join(train_class1_dir, fname) 
                for fname in train_class1_fnames[ pic_index- number_of_image : pic_index] 
                ]

next_class2_pix = [os.path.join(train_class2_dir, fname) 
                for fname in train_class2_fnames[ pic_index- number_of_image :pic_index]
                ]

for i, img_path in enumerate(next_class1_pix+next_class2_pix):
    # Set up subplot; subplot indices start at 1
    sp = plt.subplot(nrows, ncols, i + 1)
    sp.axis('Off') # Don't show axes (or gridlines)

    img = mpimg.imread(img_path)
    plt.imshow(img)

plt.show()

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-64156d691fe5> in <module>
# ----> 1 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import tens
