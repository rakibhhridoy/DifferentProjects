# %%
# %matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(3,2)

# %%
plt.plot(3,2,'.')

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

fig = Figure()
canvas = FigureCanvasAgg(fig)
ax = fig.add_subplot(111)
ax.plot(3,2,'.')
canvas.print_png('test.png')

# %%
# %%html
# <img src = 'test.png'/>
# Out:
# <img src = 'test.png'/>

# %%
plt.figure()
plt.plot(3,2,'o')
ax = plt.gca()
ax.axis([0,6,0,10])
# Out:
# [0, 6, 0, 10]

# %%
plt.figure()
plt.plot(1.5,1.5,'o')
plt.plot(2,2,'o')
plt.plot(2.5,2.5,'o')
plt.plot(3,3,'o')

# %%
ax = plt.gca()
ax.get_children()
# Out:
# [<matplotlib.spines.Spine at 0xa94c1c8>,
#  <matplotlib.spines.Spine at 0xa944888>,
#  <matplotlib.spines.Spine at 0xb0ff948>,
#  <matplotlib.spines.Spine at 0xab0d3c8>,
#  <matplotlib.axis.XAxis at 0xa94c4c8>,
#  <matplotlib.axis.YAxis at 0xadfc708>,
#  Text(0.5, 1.0, ''),
#  Text(0.0, 1.0, ''),
#  Text(1.0, 1.0, ''),
#  <matplotlib.patches.Rectangle at 0xadde8c8>]

# %% [markdown]
# ### ScatterPlots
